# %%
import numpy as np
import os

import keras.backend as K

os.environ["CUDA_VISIBLE_DEVICES"] = '-1'

# %%
from utils.model import calc_memory_usage, plot_parameter_statistic, count_parameters
from sl_model import SL512, DSODSL512, SL384x512_dense

for name in [ 'SL512', 'DSODSL512', 'SL384x512_dense' ]:
    K.clear_session()
    model = eval(name+'()')
    print(name)
    #print(model.count_params())
    count_parameters(model)
    calc_memory_usage(model)
    plot_parameter_statistic(model, layer_types=['Dense', 'Conv2D', 'SeparableConv2D', 'DepthwiseConv2D'])
# Out:
# SL512
# trainable           24,358,681
# non-trainable                0
# model memory usage   421.30 MB
# DSODSL512
# trainable           12,825,465
# non-trainable           79,712
# model memory usage     1.50 GB
# SL384x512_dense
# trainable            5,286,426
# non-trainable           25,472
# model memory usage     1.35 GB
